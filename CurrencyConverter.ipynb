# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitha5656/AI-Bootcamp/blob/main/CurrencyConverter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

amount = float(input("Enter amount: "))
from_currency = input("From Currency: ").upper()
to_currency = input("To Currency: ").upper()

url=f"https://api.frankfurter.dev/v2/rate/{from_currency}/{to_currency}"

response = requests.get(url)

print("Status code:", response.status_code)

if response.status_code == 200:
    data = response.json()
    rate = data["rate"]
    converted_amount = amount * rate
    print(f"{amount} {from_currency} is equal to {converted_amount} {to_currency}")
else:
    print("Error:", response.status_code)
# Out:
# Enter amount: 100
# From Currency: USD
# To Currency: INR
# Status code: 200
# 100.0 USD is equal to 9590.0 INR
